# %%
import pandas as pd

# %%
import os

# %%
from datetime import datetime,timedelta

# %%
path ="C://Users/ACER/Documents/CURSOS/Formação Cientista de Dados/dados_totais"

# %%
dir_list = os.listdir(path)

# %%
print(dir_list)
# Out:
# ['olist_customers_dataset.csv', 'olist_geolocation_dataset.csv', 'olist_orders_dataset.csv', 'olist_order_items_dataset.csv', 'olist_order_payments_dataset.csv', 'olist_order_reviews_dataset.csv', 'olist_products_dataset.csv', 'olist_sellers_dataset.csv', 'orders_data.csv', 'orders_data.xlsx', 'output.csv', 'product_category_name_translation.csv']

# %%
df_orders = pd.read_csv("C://Users/ACER/Documents/CURSOS/Formação Cientista de Dados/dados_totais/olist_orders_dataset.csv")

# %%
print(df_orders)
# Out:
#                                order_id                       customer_id  \
# 0      e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1      53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2      47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3      949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4      ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                 ...                               ...
# 99436  9c5dedf39a927c1b2549525ed64a053c  39bd1228ee8140590ac3aca26f2dfe00
# 99437  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 99438  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 99439  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 99440  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#       order_status order_purchase_timestamp    order_approved_at  \
# ...

# %%
df_orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  object
#  4   order_approved_at              99281 non-null  object
#  5   order_delivered_carrier_date   97658 non-null  object
#  6   order_delivered_customer_date  96476 non-null  object
#  7   order_estimated_delivery_date  99441 non-null  object
# dtypes: object(8)
# memory usage: 6.1+ MB

# %%
df_orders=pd.read_csv("C://Users/ACER/Documents/CURSOS/Formação Cientista de Dados/dados_totais/olist_orders_dataset.csv",parse_dates=['order_purchase_timestamp', 'order_approved_at', 'order_delivered_carrier_date', 'order_delivered_customer_date', 'order_estimated_delivery_date'])

# %%
df_orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  datetime64[ns]
#  4   order_approved_at              99281 non-null  datetime64[ns]
#  5   order_delivered_carrier_date   97658 non-null  datetime64[ns]
#  6   order_delivered_customer_date  96476 non-null  datetime64[ns]
#  7   order_estimated_delivery_date  99441 non-null  datetime64[ns]
# dtypes: datetime64[ns](5), object(3)
# memory usage: 6.1+ MB

# %%
(df_orders['order_approved_at'].dt.month,df_orders['order_approved_at'].dt.day,df_orders['order_approved_at'].dt.hour)
# Out:
# (0        10.0
#  1         7.0
#  2         8.0
#  3        11.0
#  4         2.0
#           ...
#  99436     3.0
#  99437     2.0
#  99438     8.0
#  99439     1.0
#  99440     3.0
#  Name: order_approved_at, Length: 99441, dtype: float64,
#  0         2.0
#  1        26.0
#  2         8.0
#  3        18.0
#  4        13.0
#           ...
#  99436     9.0
#  99437     6.0
#  99438    27.0
#  99439     8.0
#  99440     9.0
#  Name: order_approved_at, Length: 99441, dtype: float64,
#  0        11.0
#  1         3.0
#  2         8.0
#  3        19.0
#  4        22.0
#           ...
#  99436     9.0
#  99437    13.0
#  99438    15.0
#  99439    21.0
#  99440    11.0
#  Name: order_approved_at, Length: 99441, dtype: float64)

# %%
df_orders['order_purchase_timestamp'].dt.to_period('M')
# Out:
# 0        2017-10
# 1        2018-07
# 2        2018-08
# 3        2017-11
# 4        2018-02
#           ...
# 99436    2017-03
# 99437    2018-02
# 99438    2017-08
# 99439    2018-01
# 99440    2018-03
# Name: order_purchase_timestamp, Length: 99441, dtype: period[M]

# %%
df_orders['order_purchase_timestamp'].dt.strftime('Dia %d de %B de %Y')
# Out:
# 0         Dia 02 de October de 2017
# 1            Dia 24 de July de 2018
# 2          Dia 08 de August de 2018
# 3        Dia 18 de November de 2017
# 4        Dia 13 de February de 2018
#                     ...
# 99436       Dia 09 de March de 2017
# 99437    Dia 06 de February de 2018
# 99438      Dia 27 de August de 2017
# 99439     Dia 08 de January de 2018
# 99440       Dia 08 de March de 2018
# Name: order_purchase_timestamp, Length: 99441, dtype: object

# %%
df_orders['filtro_pedidos']=pd.cut(df_orders['order_purchase_timestamp'],bins=[datetime(2017, 11, 1),datetime(2017, 11, 30)])

# %%
df_orders.sort_values(by='order_purchase_timestamp')
# Out:
#                                order_id                       customer_id  \
# 4541   2e7a8482f6fb09756ca50c10d7bfc047  08c5351a6aca1c1589a38f244edeee9d
# 4396   e5fa5a7210941f7d56d0208e4e071d35  683c54fc24d40ee9f8a6fc179fd9856c
# 10071  809a282bbd5dbcabb6f2f724fca862ec  622e13439d6b5a0b486c435618b2679e
# 30710  bfbd0f9bdef84302105ad712db648a6c  86dc2ffce2dfff336de2f386a786e574
# 83078  71303d7e93b399f5bcd537d124c0bcfa  b106b360fe2ef8849fbbd056f777b4d5
# ...                                 ...                               ...
# 50387  392ed9afd714e3c74767d0c4d3e3f477  2823ffda607a2316375088e0d00005ec
# 88500  616fa7d4871b87832197b2a137a115d2  bf6181a85bbb4115736c0a8db1a53be3
# 31891  a2ac6dad85cf8af5b0afb510a240fe8c  4c2ec60c29d10c34bd49cb88aa85cfc4
# 68373  b059ee4de278302d550a3035c4cdb740  856336203359aa6a61bf3826f7d84c49
# 60938  10a045cdf6a5650c21e9cfeb60384c16  a4b417188addbc05b26b72d5e44837a1
#
#       order_status order_purchase_timestamp   order_approved_at  \
# ...

# %%
pedidos_entregues = df_orders.query('order_status == "delivered"')

# %%
duracao_envio_entrega=pedidos_entregues['order_delivered_customer_date'] -pedidos_entregues['order_delivered_carrier_date']

# %%
duracao_envio_entrega
# Out:
# 0        6 days 01:30:13
# 1       12 days 00:56:45
# 2        9 days 04:16:29
# 3        9 days 10:48:43
# 4        1 days 22:30:28
#               ...
# 99436    7 days 03:49:58
# 99437   20 days 18:15:14
# 99438   23 days 14:31:51
# 99439   13 days 07:57:51
# 99440    6 days 14:56:31
# Length: 96478, dtype: timedelta64[ns]

# %%
duracao_envio_entrega
# Out:
# 0        6 days 01:30:13
# 1       12 days 00:56:45
# 2        9 days 04:16:29
# 3        9 days 10:48:43
# 4        1 days 22:30:28
#               ...
# 99436    7 days 03:49:58
# 99437   20 days 18:15:14
# 99438   23 days 14:31:51
# 99439   13 days 07:57:51
# 99440    6 days 14:56:31
# Length: 96478, dtype: timedelta64[ns]

# %%
media_duracao_envio_entrega =  duracao_envio_entrega.dt.days.mean()

# %%
media_duracao_envio_entrega
# Out:
# 8.878054089914896

# %%
prazo_prometido = pedidos_entregues['order_estimated_delivery_date']-pedidos_entregues['order_delivered_carrier_date']

# %%
prazo_prometido.dt.days.mean()
# Out:
# 20.158567933993947

# %%
df_orders.set_index('order_delivered_customer_date').loc['2017-12-24':'2017-12-25']
# Out:
# C:\Users\ACER\AppData\Local\Temp/ipykernel_12176/3756659777.py:1: FutureWarning: Value based partial slicing on non-monotonic DatetimeIndexes with non-existing keys is deprecated and will raise a KeyError in a future Version.
#   df_orders.set_index('order_delivered_customer_date').loc['2017-12-24':'2017-12-25']
#                                                        order_id  \
# order_delivered_customer_date
# 2017-12-24 12:16:47            a05cabeed82a5a2e8078c7e6ed14a03a
# 2017-12-24 14:58:31            53183a96aacc31f11503c049f49905a3
# 2017-12-24 14:18:41            cfeafb929e8e089a77a5941999a6c608
# 2017-12-24 10:28:02            638c43326cd8c7403a2bf818e46b779e
# 2017-12-24 13:39:00            90346710cfeac855230fe9a162980274
# 2017-12-24 12:51:59            9e98c3552018458c0a2dbfda35bbfbfb
# 2017-12-24 13:29:07            791de4d00367a315bd14eb6ea519adef
# 2017-12-24 12:59:50            c0f2ea4b21ba7cf42168794fcc92560a
# ...

# %%
df_orders.set_index('order_purchase_timestamp').resample('M')

# %%
df_orders.set_index('order_purchase_timestamp').resample('M')['order_id'].count()
# Out:
# order_purchase_timestamp
# 2016-09-30       4
# 2016-10-31     324
# 2016-11-30       0
# 2016-12-31       1
# 2017-01-31     800
# 2017-02-28    1780
# 2017-03-31    2682
# 2017-04-30    2404
# 2017-05-31    3700
# 2017-06-30    3245
# 2017-07-31    4026
# 2017-08-31    4331
# 2017-09-30    4285
# 2017-10-31    4631
# 2017-11-30    7544
# 2017-12-31    5673
# 2018-01-31    7269
# 2018-02-28    6728
# 2018-03-31    7211
# 2018-04-30    6939
# 2018-05-31    6873
# 2018-06-30    6167
# 2018-07-31    6292
# 2018-08-31    6512
# 2018-09-30      16
# 2018-10-31       4
# Freq: M, Name: order_id, dtype: int64

# %%
df_orders[['order_purchase_timestamp']].drop_duplicates().set_index('order_purchase_timestamp').resample('12H').asfreq()
# Out:
# Empty DataFrame
# Columns: []
# ...

# %%
df_orders['ano_mes_compra'] =df_orders['order_purchase_timestamp'].dt.to_period('M')

# %%
pedidos_por_mes_ano=df_orders.groupby('ano_mes_compra')[['order_id']].count()

# %%
pedidos_por_mes_ano.index=pedidos_por_mes_ano.index.to_timestamp()

# %%
pedidos_por_mes_ano
# Out:
#                 order_id
# ano_mes_compra
# 2016-09-01             4
# 2016-10-01           324
# 2016-12-01             1
# 2017-01-01           800
# 2017-02-01          1780
# 2017-03-01          2682
# 2017-04-01          2404
# 2017-05-01          3700
# 2017-06-01          3245
# 2017-07-01          4026
# 2017-08-01          4331
# 2017-09-01          4285
# 2017-10-01          4631
# 2017-11-01          7544
# 2017-12-01          5673
# 2018-01-01          7269
# 2018-02-01          6728
# 2018-03-01          7211
# 2018-04-01          6939
# 2018-05-01          6873
# 2018-06-01          6167
# 2018-07-01          6292
# 2018-08-01          6512
# 2018-09-01            16
# 2018-10-01             4

# %%
new_date_index_range=pd.date_range(start='2016-01-01',end='2018-12-01',freq='MS')

# %%
pedidos_por_mes_ano.reindex(new_date_index_range)
# Out:
#             order_id
# 2016-01-01       NaN
# 2016-02-01       NaN
# 2016-03-01       NaN
# 2016-04-01       NaN
# 2016-05-01       NaN
# 2016-06-01       NaN
# 2016-07-01       NaN
# 2016-08-01       NaN
# 2016-09-01       4.0
# 2016-10-01     324.0
# 2016-11-01       NaN
# 2016-12-01       1.0
# 2017-01-01     800.0
# 2017-02-01    1780.0
# 2017-03-01    2682.0
# 2017-04-01    2404.0
# 2017-05-01    3700.0
# 2017-06-01    3245.0
# 2017-07-01    4026.0
# 2017-08-01    4331.0
# 2017-09-01    4285.0
# 2017-10-01    4631.0
# 2017-11-01    7544.0
# 2017-12-01    5673.0
# 2018-01-01    7269.0
# 2018-02-01    6728.0
# 2018-03-01    7211.0
# 2018-04-01    6939.0
# 2018-05-01    6873.0
# 2018-06-01    6167.0
# 2018-07-01    6292.0
# 2018-08-01    6512.0
# 2018-09-01      16.0
# 2018-10-01       4.0
# 2018-11-01       NaN
# 2018-12-01       NaN

# %%
df_products=pd.read_csv('C://Users/ACER/Documents/CURSOS/Formação Cientista de Dados/dados_totais/olist_products_dataset.csv')

# %%
tb_telefonia=df_products.query('product_category_name == "telefonia" and product_photos_qty > 5')

# %%
tb_telefonia
# Out:
#                              product_id product_category_name  \
# 118    7f6308ba4057a6a740af7b4dcfb79c13             telefonia
# 175    4473f3e5c65952b074ef987fa5c24662             telefonia
# 316    bb31a27a0b24236c8ce7e0c6264c51ec             telefonia
# 410    a453b4ccccf554efba31d5ada5a59a60             telefonia
# 637    afb0d399cb1dec68de437eec41c94fad             telefonia
# ...                                 ...                   ...
# 31762  c91fd1bf3e75d3b29370483ffda5eee0             telefonia
# 31941  b51485801348808e02617629d896c936             telefonia
# 32056  5d98f7de3b78c8dd8d7b62ea22000a65             telefonia
# 32272  8cefe1c6f2304e7e6825150218ffc58c             telefonia
# 32339  9fee00e0df0ae090525db9ad0dd73cb8             telefonia
#
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# 118                   63.0                      1930.0                 9.0
# ...

# %%
tb_eletronicos=df_products.query('product_category_name == "eletronicos" and product_photos_qty > 5')[['product_id', 'product_category_name', 'product_photos_qty']]

# %%
tb_eletronicos
# Out:
#                              product_id product_category_name  \
# 2771   93c902b021a9e594f658ab1b0351602a           eletronicos
# 4244   98e0de96ebb0711db1fc3d1bad1a902f           eletronicos
# 5343   40002041835941ae0e10b9716ab7b03d           eletronicos
# 7930   78f8812dd6c26f65ff9cd09b0318090c           eletronicos
# 10538  0abc19e41fdc9d6894b8cae651619253           eletronicos
# 11892  9b37a918bcf2c8e1064e867cf1df4637           eletronicos
# 15378  c714f103a677fbcc818799ae0fcda11a           eletronicos
# 20133  f84ca2376ed799523593afad3bdae70f           eletronicos
# 22681  01cf56cd6138b926a4802d16fc304149           eletronicos
# 23192  93566f7e511c3e7472b05758fa08e64d           eletronicos
# 27826  9ff8568dfb9041b898e65ff4018c8c57           eletronicos
# 29296  7af4c96f817389692dfb05e679dbd991           eletronicos
# 30521  63bfa27a0cee21fd896dc27f58b6d656           eletronicos
#
#        product_photos_qty
# 2771                  7.0
# 4244                  6.0
# ...

# %%
tb_telefonia.append(tb_eletronicos)
# Out:
#                              product_id product_category_name  \
# 118    7f6308ba4057a6a740af7b4dcfb79c13             telefonia
# 175    4473f3e5c65952b074ef987fa5c24662             telefonia
# 316    bb31a27a0b24236c8ce7e0c6264c51ec             telefonia
# 410    a453b4ccccf554efba31d5ada5a59a60             telefonia
# 637    afb0d399cb1dec68de437eec41c94fad             telefonia
# ...                                 ...                   ...
# 22681  01cf56cd6138b926a4802d16fc304149           eletronicos
# 23192  93566f7e511c3e7472b05758fa08e64d           eletronicos
# 27826  9ff8568dfb9041b898e65ff4018c8c57           eletronicos
# 29296  7af4c96f817389692dfb05e679dbd991           eletronicos
# 30521  63bfa27a0cee21fd896dc27f58b6d656           eletronicos
#
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# 118                   63.0                      1930.0                 9.0
# ...

# %%
pd.concat([tb_telefonia,tb_eletronicos])
# Out:
#                              product_id product_category_name  \
# 118    7f6308ba4057a6a740af7b4dcfb79c13             telefonia
# 175    4473f3e5c65952b074ef987fa5c24662             telefonia
# 316    bb31a27a0b24236c8ce7e0c6264c51ec             telefonia
# 410    a453b4ccccf554efba31d5ada5a59a60             telefonia
# 637    afb0d399cb1dec68de437eec41c94fad             telefonia
# ...                                 ...                   ...
# 22681  01cf56cd6138b926a4802d16fc304149           eletronicos
# 23192  93566f7e511c3e7472b05758fa08e64d           eletronicos
# 27826  9ff8568dfb9041b898e65ff4018c8c57           eletronicos
# 29296  7af4c96f817389692dfb05e679dbd991           eletronicos
# 30521  63bfa27a0cee21fd896dc27f58b6d656           eletronicos
#
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# 118                   63.0                      1930.0                 9.0
# ...

# %%
df_orders=pd.read_csv('C://Users/ACER/Documents/CURSOS/Formação Cientista de Dados/dados_totais/olist_orders_dataset.csv',usecols= ['order_id', 'order_status'])

# %%
df_payments=pd.read_csv('C://Users/ACER/Documents/CURSOS/Formação Cientista de Dados/dados_totais/olist_order_payments_dataset.csv',usecols= ['order_id', 'payment_type', 'payment_value'])

# %%
orders=df_orders.set_index('order_id').sort_index()

# %%
payments=df_payments.groupby('order_id')['payment_value'].sum()

# %%
payments
# Out:
# order_id
# 00010242fe8c5a6d1ba2dd792cb16214     72.19
# 00018f77f2f0320c557190d7a144bdd3    259.83
# 000229ec398224ef6ca0657da4fc703e    216.87
# 00024acbcdf0a6daa1e931b038114c75     25.78
# 00042b26cf59d7ce69dfabb4e55b4fd9    218.04
#                                      ...
# fffc94f6ce00a00581880bf54a75a037    343.40
# fffcd46ef2263f404302a634eb57f7eb    386.53
# fffce4705a9662cd70adb13d4a31832d    116.85
# fffe18544ffabc95dfada21779c9644f     64.71
# fffe41c64501cc87c801fd61db3f6244     55.79
# Name: payment_value, Length: 99440, dtype: float64

# %%
pd.concat([orders,payments],axis=1)
# Out:
#                                  order_status  payment_value
# order_id
# 00010242fe8c5a6d1ba2dd792cb16214    delivered          72.19
# 00018f77f2f0320c557190d7a144bdd3    delivered         259.83
# 000229ec398224ef6ca0657da4fc703e    delivered         216.87
# 00024acbcdf0a6daa1e931b038114c75    delivered          25.78
# 00042b26cf59d7ce69dfabb4e55b4fd9    delivered         218.04
# ...                                       ...            ...
# fffc94f6ce00a00581880bf54a75a037    delivered         343.40
# fffcd46ef2263f404302a634eb57f7eb    delivered         386.53
# fffce4705a9662cd70adb13d4a31832d    delivered         116.85
# fffe18544ffabc95dfada21779c9644f    delivered          64.71
# fffe41c64501cc87c801fd61db3f6244    delivered          55.79
#
# [99441 rows x 2 columns]

# %%
df_orders.merge(df_payments,on='order_id')
# Out:
#                                 order_id order_status payment_type  \
# 0       e481f51cbdc54678b7cc49136f2d6af7    delivered  credit_card
# 1       e481f51cbdc54678b7cc49136f2d6af7    delivered      voucher
# 2       e481f51cbdc54678b7cc49136f2d6af7    delivered      voucher
# 3       53cdb2fc8bc7dce0b6741e2150273451    delivered       boleto
# 4       47770eb9100c2d0c44946d9cf07ec65d    delivered  credit_card
# ...                                  ...          ...          ...
# 103881  9c5dedf39a927c1b2549525ed64a053c    delivered  credit_card
# 103882  63943bddc261676b46f01ca7ac2f7bd8    delivered  credit_card
# 103883  83c1379a015df1e13d02aae0204711ab    delivered  credit_card
# 103884  11c177c8e97725db2631073c19f07b62    delivered  credit_card
# 103885  66dea50a8b16d9b4dee7af250b4be1a5    delivered   debit_card
#
#         payment_value
# 0               18.12
# 1                2.00
# 2               18.59
# 3              141.46
# 4              179.12
# ...

# %%
df_items=pd.read_csv('C://Users/ACER/Documents/CURSOS/Formação Cientista de Dados/dados_totais/olist_order_items_dataset.csv')

# %%
df_reviews=pd.read_csv('C://Users/ACER/Documents/CURSOS/Formação Cientista de Dados/dados_totais/olist_order_reviews_dataset.csv')

# %%
print(df_items.info(),df_reviews.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   order_id             112650 non-null  object
#  1   order_item_id        112650 non-null  int64
#  2   product_id           112650 non-null  object
#  3   seller_id            112650 non-null  object
#  4   shipping_limit_date  112650 non-null  object
#  5   price                112650 non-null  float64
#  6   freight_value        112650 non-null  float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 6.0+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99224 entries, 0 to 99223
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   review_id                99224 non-null  object
#  1   order_id                 99224 non-null  object
# ...

# %%
Merge_seller_product = df_items.merge(df_reviews.dropna(subset=['review_comment_message']),on='order_id',how='right').sort_values(by=['order_id', 'product_id'])

# %%
Merge_seller_product
# Out:
#                                order_id  order_item_id  \
# 25308  00010242fe8c5a6d1ba2dd792cb16214            1.0
# 2078   000229ec398224ef6ca0657da4fc703e            1.0
# 27053  00042b26cf59d7ce69dfabb4e55b4fd9            1.0
# 32924  0005a1a1728c9d785b8e2b08b904576c            1.0
# 12154  00061f2a7bc09da83e415a52dc8a4af1            1.0
# ...                                 ...            ...
# 41852  ffeeb911d070bea3dd20bd5fd01da5e8            1.0
# 4559   fff8287bbae429a99bb7e8c21d151c41            1.0
# 4560   fff8287bbae429a99bb7e8c21d151c41            2.0
# 7056   fffb0b1a50e65c449020434fa835e078            1.0
# 24536  fffe18544ffabc95dfada21779c9644f            1.0
#
#                              product_id                         seller_id  \
# 25308  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 2078   c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 27053  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
# ...

# %%
Valor_maximo = Merge_seller_product.max()
# Out:
# C:\Users\ACER\AppData\Local\Temp/ipykernel_12176/1567004094.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   Valor_maximo = Merge_seller_product.max()

# %%
Valor_maximo
# Out:
# order_id                                    fffe18544ffabc95dfada21779c9644f
# order_item_id                                                           21.0
# price                                                                 6735.0
# freight_value                                                         375.28
# review_id                                   fffd68e8a9fb73a56a2f504011b0f1f1
# review_score                                                               5
# review_comment_message     😡😡😡😡😡👎👎👎👎👎\r\nEmpresa sem compromisso com o cl...
# review_creation_date                                     2018-08-31 00:00:00
# review_answer_timestamp                                  2018-10-24 21:34:38
# dtype: object

# %%
Merge_seller_product.sort_values(by='price', ascending=False).head(1)
# Out:
#                                order_id  order_item_id  \
# 23935  0812eb902a67711a1cb742b3cdaa65ae            1.0
#
#                              product_id                         seller_id  \
# 23935  489ae2aa008f021502940f251d4cce7f  e3b4998c7a498169dc7bce44e6bb6277
#
#        shipping_limit_date   price  freight_value  \
# 23935  2017-02-16 20:37:36  6735.0         194.31
#
#                               review_id  review_score review_comment_title  \
# 23935  e2fbd9f0ef7b724c7ecb351601a857e7             5                  NaN
#
#                                   review_comment_message review_creation_date  \
# 23935  Mesmo a máquina ter vindo errada, já se pronti...  2017-03-04 00:00:00
#
#       review_answer_timestamp
# 23935     2017-03-04 21:40:41

# %%
df_products=pd.read_csv('C://Users/ACER/Documents/CURSOS/Formação Cientista de Dados/dados_totais/olist_products_dataset.csv')

# %%
df_products
# Out:
#                              product_id              product_category_name  \
# 0      1e9e8ef04dbcff4541ed26657ea517e5                         perfumaria
# 1      3aa071139cb16b67ca9e5dea641aaa2f                              artes
# 2      96bd76ec8810374ed1b65e291975717f                      esporte_lazer
# 3      cef67bcfe19066a932b7673e239eb23d                              bebes
# 4      9dc1a7de274444849c219cff195d0b71              utilidades_domesticas
# ...                                 ...                                ...
# 32946  a0b7d5a992ccda646f2d34e418fff5a0                   moveis_decoracao
# 32947  bf4538d88321d0fd4412a93c974510e6  construcao_ferramentas_iluminacao
# 32948  9a7c6041fa9592d9d9ef6cfe62a71f8c                    cama_mesa_banho
# 32949  83808703fc0706a22e264b9d75f04a2e             informatica_acessorios
# 32950  106392145fca363410d287a815be6de4                    cama_mesa_banho
#
# ...

# %%
df_payments=pd.read_csv('C://Users/ACER/Documents/CURSOS/Formação Cientista de Dados/dados_totais/olist_order_payments_dataset.csv',usecols= ['order_id', 'payment_type', 'payment_value'])

# %%
df_payments
# Out:
#                                 order_id payment_type  payment_value
# 0       b81ef226f3fe1789b1e8b2acac839d17  credit_card          99.33
# 1       a9810da82917af2d9aefd1278f1dcfa0  credit_card          24.39
# 2       25e8ea4e93396b6fa0d3dd708e76c1bd  credit_card          65.71
# 3       ba78997921bbcdc1373bb41e913ab953  credit_card         107.78
# 4       42fdf880ba16b47b59251dd489d4441a  credit_card         128.45
# ...                                  ...          ...            ...
# 103881  0406037ad97740d563a178ecc7a2075c       boleto         363.31
# 103882  7b905861d7c825891d6347454ea7863f  credit_card          96.80
# 103883  32609bbb3dd69b3c066a6860554a77bf  credit_card          47.77
# 103884  b8b61059626efa996a60be9bb9320e10  credit_card         369.54
# 103885  28bbae6599b09d39ca406b747b6632b1       boleto         191.58
#
# [103886 rows x 3 columns]

# %%
df_products=pd.read_csv('C://Users/ACER/Documents/CURSOS/Formação Cientista de Dados/dados_totais/olist_products_dataset.csv')

# %%
df_products
# Out:
#                              product_id              product_category_name  \
# 0      1e9e8ef04dbcff4541ed26657ea517e5                         perfumaria
# 1      3aa071139cb16b67ca9e5dea641aaa2f                              artes
# 2      96bd76ec8810374ed1b65e291975717f                      esporte_lazer
# 3      cef67bcfe19066a932b7673e239eb23d                              bebes
# 4      9dc1a7de274444849c219cff195d0b71              utilidades_domesticas
# ...                                 ...                                ...
# 32946  a0b7d5a992ccda646f2d34e418fff5a0                   moveis_decoracao
# 32947  bf4538d88321d0fd4412a93c974510e6  construcao_ferramentas_iluminacao
# 32948  9a7c6041fa9592d9d9ef6cfe62a71f8c                    cama_mesa_banho
# 32949  83808703fc0706a22e264b9d75f04a2e             informatica_acessorios
# 32950  106392145fca363410d287a815be6de4                    cama_mesa_banho
#
# ...

# %%
df_items=pd.read_csv('C://Users/ACER/Documents/CURSOS/Formação Cientista de Dados/dados_totais/olist_order_items_dataset.csv')

# %%
df_items
# Out:
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       00018f77f2f0320c557190d7a144bdd3              1
# 2       000229ec398224ef6ca0657da4fc703e              1
# 3       00024acbcdf0a6daa1e931b038114c75              1
# 4       00042b26cf59d7ce69dfabb4e55b4fd9              1
# ...                                  ...            ...
# 112645  fffc94f6ce00a00581880bf54a75a037              1
# 112646  fffcd46ef2263f404302a634eb57f7eb              1
# 112647  fffce4705a9662cd70adb13d4a31832d              1
# 112648  fffe18544ffabc95dfada21779c9644f              1
# 112649  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1       e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# ...

# %%
df_items.merge(df_products,on='product_id')
# Out:
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       130898c0987d1801452a8ed92a670612              1
# 2       532ed5e14e24ae1f0d735b91524b98b9              1
# 3       6f8c31653edb8c83e1a739408b5ff750              1
# 4       7d19f4ef4d04461989632411b7e588b9              1
# ...                                  ...            ...
# 112645  ffebd80e3291e811c308365936897efd              1
# 112646  ffee31fb4b5e35c9123608015637c495              1
# 112647  fff7c4452f050315db1b3f24d9df5fcd              1
# 112648  fffa82886406ccf10c7b4e35c4ff2788              1
# 112649  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# ...

# %%
Merge_itens_merge_products = df_items.merge(df_products,on='product_id')

# %%
Merge_itens_merge_products.sort_values(by='price', ascending=False).head(1)
# Out:
#                                order_id  order_item_id  \
# 37101  0812eb902a67711a1cb742b3cdaa65ae              1
#
#                              product_id                         seller_id  \
# 37101  489ae2aa008f021502940f251d4cce7f  e3b4998c7a498169dc7bce44e6bb6277
#
#        shipping_limit_date   price  freight_value  product_category_name  \
# 37101  2017-02-16 20:37:36  6735.0         194.31  utilidades_domesticas
#
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# 37101                 31.0                       875.0                 2.0
#
#        product_weight_g  product_length_cm  product_height_cm  \
# 37101           30000.0               60.0               61.0
#
#        product_width_cm
# 37101              33.0

# %%
categoria_mais_rentavel=Merge_itens_merge_products.groupby('price')[['product_category_name']].sum()

# %%
categoria_mais_rentavel.sort_values(by='price', ascending=False).head(1)
# Out:
#         product_category_name
# price
# 6735.0  utilidades_domesticas

# %%
maior_numero_de_vendas_categoria=Merge_itens_merge_products.groupby('product_category_name')[['order_id']].count().head(1)

# %%
data_dos_pedidos = pd.read_csv('C://Users/ACER/Documents/CURSOS/Formação Cientista de Dados/dados_totais/olist_order_items_dataset.csv', 
                          index_col='order_id',
                          usecols=['order_id', 'shipping_limit_date'],
                          parse_dates=['shipping_limit_date'])\
    .query('shipping_limit_date >= "2018-01-01" and shipping_limit_date <= "2018-12-31"')
data_dos_pedidos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 62511 entries, 000229ec398224ef6ca0657da4fc703e to fffe41c64501cc87c801fd61db3f6244
# Data columns (total 1 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   shipping_limit_date  62511 non-null  datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 976.7+ KB

# %%
data_dos_pedidos
# Out:
#                                  shipping_limit_date
# order_id
# 000229ec398224ef6ca0657da4fc703e 2018-01-18 14:48:30
# 00024acbcdf0a6daa1e931b038114c75 2018-08-15 10:10:18
# 000576fe39319847cbb9d288c5617fa6 2018-07-10 12:30:45
# 0005a1a1728c9d785b8e2b08b904576c 2018-03-26 18:31:29
# 0005f50442cb953dcd1d21e1fb923495 2018-07-06 14:10:56
# ...                                              ...
# fffb2ef8874127f75b52b643880fd7e0 2018-04-09 05:08:33
# fffbee3b5462987e66fb49b1c5411df2 2018-06-28 09:58:03
# fffc94f6ce00a00581880bf54a75a037 2018-05-02 04:11:01
# fffcd46ef2263f404302a634eb57f7eb 2018-07-20 04:31:48
# fffe41c64501cc87c801fd61db3f6244 2018-06-12 17:10:13
#
# [62511 rows x 1 columns]

# %%
Merge_itens_data = df_items.merge(data_dos_pedidos,on='order_id')

# %%
Merge_itens_data
# Out:
#                                order_id  order_item_id  \
# 0      000229ec398224ef6ca0657da4fc703e              1
# 1      00024acbcdf0a6daa1e931b038114c75              1
# 2      000576fe39319847cbb9d288c5617fa6              1
# 3      0005a1a1728c9d785b8e2b08b904576c              1
# 4      0005f50442cb953dcd1d21e1fb923495              1
# ...                                 ...            ...
# 87200  fffb2ef8874127f75b52b643880fd7e0              1
# 87201  fffbee3b5462987e66fb49b1c5411df2              1
# 87202  fffc94f6ce00a00581880bf54a75a037              1
# 87203  fffcd46ef2263f404302a634eb57f7eb              1
# 87204  fffe41c64501cc87c801fd61db3f6244              1
#
#                              product_id                         seller_id  \
# 0      c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 1      7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 2      557d850972a7d6f792fd18ae1400d9b6  5996cddab893a4652a15592fb58ab8db
# ...

# %%
Merge_itens_merge_products = Merge_itens_data.merge(df_products,on='product_id')

# %%
Merge_itens_merge_products.sort_values(by='price', ascending=False).head(1)
# Out:
#                                order_id  order_item_id  \
# 87139  fefacc66af859508bf1a7934eab1e97f              1
#
#                              product_id                         seller_id  \
# 87139  69c590f7ffc7bf8db97190b6cb6ed62e  80ceebb4ee9b31afb6c6a916a574a1e2
#
#       shipping_limit_date_x   price  freight_value shipping_limit_date_y  \
# 87139   2018-08-02 04:05:13  6729.0         193.21   2018-08-02 04:05:13
#
#       product_category_name  product_name_lenght  product_description_lenght  \
# 87139                   pcs                 50.0                      1935.0
#
#        product_photos_qty  product_weight_g  product_length_cm  \
# 87139                 4.0            5660.0               54.0
#
#        product_height_cm  product_width_cm
# 87139               18.0              47.0

# %%
categoria_mais_rentavel=Merge_itens_merge_products.groupby('price')[['product_category_name']].sum()

# %%
categoria_mais_rentavel.sort_values(by='price', ascending=False).head(1)
# Out:
#        product_category_name
# price
# 6729.0                   pcs

# %%
produto_com_mais_vendas = Merge_itens_merge_products.groupby('product_category_name')[['order_id']].count()

# %%
produto_com_mais_vendas
# Out:
#                            order_id
# product_category_name
# agro_industria_e_comercio       210
# alimentos                       512
# alimentos_bebidas               243
# artes                           180
# artes_e_artesanato               25
# ...                             ...
# sinalizacao_e_seguranca         329
# tablets_impressao_imagem         27
# telefonia                      3220
# telefonia_fixa                  152
# utilidades_domesticas          6636
#
# [72 rows x 1 columns]

# %%
produto_com_mais_vendas.sort_values(by='order_id', ascending=False).head(1)
# Out:
#                        order_id
# product_category_name
# cama_mesa_banho            8928

# %%
df_review = pd.read_csv('C://Users/ACER/Documents/CURSOS/Formação Cientista de Dados/dados_totais/olist_order_reviews_dataset.csv')

# %%
df_review
# Out:
#                               review_id                          order_id  \
# 0      7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1      80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2      228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3      e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4      f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
# ...                                 ...                               ...
# 99219  574ed12dd733e5fa530cfd4bbf39d7c9  2a8c23fee101d4d5662fa670396eb8da
# 99220  f3897127253a9592a73be9bdfdf4ed7a  22ec9f0669f784db00fa86d035cf8602
# 99221  b3de70c89b1510c4cd3d0649fd302472  55d4004744368f5571d1f590031933e4
# 99222  1adeb9d84d72fe4e337617733eb85149  7725825d039fc1f0ceb7635e3f7d9206
# 99223  efe49f1d6f951dd88b51e6ccd4cc548f  90531360ecb1eec2a1fbb265a0db0508
#
#        review_score review_comment_title  \
# ...

# %%
Merge_itens_merge_products
# Out:
#                                order_id  order_item_id  \
# 0      000229ec398224ef6ca0657da4fc703e              1
# 1      7a5d50c22fa322a528d125a704c8270c              1
# 2      00024acbcdf0a6daa1e931b038114c75              1
# 3      bd486e41e0b895151c98b33db1504f8d              1
# 4      000576fe39319847cbb9d288c5617fa6              1
# ...                                 ...            ...
# 87200  ffe63ac8de50ca1b8d8aba30d6bff4fb              1
# 87201  ffebd80e3291e811c308365936897efd              1
# 87202  ffee31fb4b5e35c9123608015637c495              1
# 87203  fff1e3e76b816bfe8ef16678cc53c643              1
# 87204  fffe41c64501cc87c801fd61db3f6244              1
#
#                              product_id                         seller_id  \
# 0      c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 1      c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 2      7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# ...

# %%
Merge_reviews = Merge_itens_merge_products.merge(df_review,on='order_id')

# %%
Merge_reviews
# Out:
#                                order_id  order_item_id  \
# 0      000229ec398224ef6ca0657da4fc703e              1
# 1      7a5d50c22fa322a528d125a704c8270c              1
# 2      00024acbcdf0a6daa1e931b038114c75              1
# 3      bd486e41e0b895151c98b33db1504f8d              1
# 4      000576fe39319847cbb9d288c5617fa6              1
# ...                                 ...            ...
# 86801  ffe63ac8de50ca1b8d8aba30d6bff4fb              1
# 86802  ffebd80e3291e811c308365936897efd              1
# 86803  ffee31fb4b5e35c9123608015637c495              1
# 86804  fff1e3e76b816bfe8ef16678cc53c643              1
# 86805  fffe41c64501cc87c801fd61db3f6244              1
#
#                              product_id                         seller_id  \
# 0      c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 1      c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 2      7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# ...

# %%
produto_com_mais_avaliacoes = Merge_reviews.groupby('product_category_name')[['review_id']].count()

# %%
produto_com_mais_avaliacoes
# Out:
#                            review_id
# product_category_name
# agro_industria_e_comercio        210
# alimentos                        498
# alimentos_bebidas                243
# artes                            178
# artes_e_artesanato                25
# ...                              ...
# sinalizacao_e_seguranca          329
# tablets_impressao_imagem          27
# telefonia                       3203
# telefonia_fixa                   152
# utilidades_domesticas           6608
#
# [72 rows x 1 columns]

# %%
produto_com_mais_avaliacoes.sort_values(by='review_id', ascending=False).head(1)
# Out:
#                        review_id
# product_category_name
# cama_mesa_banho             8868

# %%
produto_com_maior_score = Merge_reviews.groupby('product_category_name')[['review_score']].sum()

# %%
produto_com_maior_score
# Out:
#                            review_score
# product_category_name
# agro_industria_e_comercio           892
# alimentos                          2021
# alimentos_bebidas                  1074
# artes                               688
# artes_e_artesanato                   96
# ...                                 ...
# sinalizacao_e_seguranca            1351
# tablets_impressao_imagem            104
# telefonia                         11567
# telefonia_fixa                      459
# utilidades_domesticas             24576
#
# [72 rows x 1 columns]

# %%
produto_com_maior_score.sort_values(by='review_score', ascending=False).head(1)
# Out:
#                        review_score
# product_category_name
# cama_mesa_banho               33119

# %%
produto_com_maior_score.sort_values(by='review_score', ascending=True).head(1)
# Out:
#                        review_score
# product_category_name
# cds_dvds_musicais                 5

# %%
df_items=pd.read_csv('C://Users/ACER/Documents/CURSOS/Formação Cientista de Dados/dados_totais/olist_order_items_dataset.csv')

# %%
df_items
# Out:
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       00018f77f2f0320c557190d7a144bdd3              1
# 2       000229ec398224ef6ca0657da4fc703e              1
# 3       00024acbcdf0a6daa1e931b038114c75              1
# 4       00042b26cf59d7ce69dfabb4e55b4fd9              1
# ...                                  ...            ...
# 112645  fffc94f6ce00a00581880bf54a75a037              1
# 112646  fffcd46ef2263f404302a634eb57f7eb              1
# 112647  fffce4705a9662cd70adb13d4a31832d              1
# 112648  fffe18544ffabc95dfada21779c9644f              1
# 112649  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1       e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# ...

# %%
df_products=pd.read_csv('C://Users/ACER/Documents/CURSOS/Formação Cientista de Dados/dados_totais/olist_products_dataset.csv')

# %%
df_category_products=pd.read_csv('C://Users/ACER/Documents/CURSOS/Formação Cientista de Dados/dados_totais/product_category_name_translation.csv')

# %%
df_items=pd.read_csv('C://Users/ACER/Documents/CURSOS/Formação Cientista de Dados/dados_totais/olist_order_items_dataset.csv')

# %%
itens_e_produtos = df_items.merge(df_products,on='product_id')

# %%
itens_e_produtos
# Out:
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       130898c0987d1801452a8ed92a670612              1
# 2       532ed5e14e24ae1f0d735b91524b98b9              1
# 3       6f8c31653edb8c83e1a739408b5ff750              1
# 4       7d19f4ef4d04461989632411b7e588b9              1
# ...                                  ...            ...
# 112645  ffebd80e3291e811c308365936897efd              1
# 112646  ffee31fb4b5e35c9123608015637c495              1
# 112647  fff7c4452f050315db1b3f24d9df5fcd              1
# 112648  fffa82886406ccf10c7b4e35c4ff2788              1
# 112649  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# ...

# %%
produtos_itens = df_items.merge(df_products,on='product_id')

# %%
produtos_itens
# Out:
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       130898c0987d1801452a8ed92a670612              1
# 2       532ed5e14e24ae1f0d735b91524b98b9              1
# 3       6f8c31653edb8c83e1a739408b5ff750              1
# 4       7d19f4ef4d04461989632411b7e588b9              1
# ...                                  ...            ...
# 112645  ffebd80e3291e811c308365936897efd              1
# 112646  ffee31fb4b5e35c9123608015637c495              1
# 112647  fff7c4452f050315db1b3f24d9df5fcd              1
# 112648  fffa82886406ccf10c7b4e35c4ff2788              1
# 112649  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# ...

# %%
Merge_itens_merge_products = df_items.merge(df_products,on='product_id')

# %%
Merge_itens_merge_products
# Out:
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       130898c0987d1801452a8ed92a670612              1
# 2       532ed5e14e24ae1f0d735b91524b98b9              1
# 3       6f8c31653edb8c83e1a739408b5ff750              1
# 4       7d19f4ef4d04461989632411b7e588b9              1
# ...                                  ...            ...
# 112645  ffebd80e3291e811c308365936897efd              1
# 112646  ffee31fb4b5e35c9123608015637c495              1
# 112647  fff7c4452f050315db1b3f24d9df5fcd              1
# 112648  fffa82886406ccf10c7b4e35c4ff2788              1
# 112649  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# ...

# %%
tkm_categorias = Merge_itens_merge_products\
    .groupby('product_category_name')\
    ['price']\
    .mean()\
    .sort_values(ascending=False)

# %%
tkm_categorias
# Out:
# product_category_name
# pcs                            1098.340542
# portateis_casa_forno_e_cafe     624.285658
# eletrodomesticos_2              476.124958
# agro_industria_e_comercio       342.124858
# instrumentos_musicais           281.616000
#                                   ...
# alimentos_bebidas                54.602446
# cds_dvds_musicais                52.142857
# fraldas_higiene                  40.194615
# flores                           33.637576
# casa_conforto_2                  25.342333
# Name: price, Length: 73, dtype: float64

# %%
Merge_itens_merge_products.sort_values(by='price', ascending=False)
# Out:
#                                 order_id  order_item_id  \
# 37101   0812eb902a67711a1cb742b3cdaa65ae              1
# 112569  fefacc66af859508bf1a7934eab1e97f              1
# 111726  f5136e38d1a14a4dbd87dff67da82701              1
# 103335  a96610ab360d42a2e5335a3998b4718a              1
# 60252   199af31afc78c699f0dbf71fb178d4d4              1
# ...                                  ...            ...
# 97511   8272b63d03f5f79c56e9e4120aec44ef              1
# 97521   8272b63d03f5f79c56e9e4120aec44ef              2
# 80496   3ee6513ae7ea23bdfab5b9ab60bffcb5              1
# 80497   6e864b3f0ec71031117ad4cf46b7f2a1              1
# 80498   c5bdd8ef3c0ec420232e668302179113              2
#
#                               product_id                         seller_id  \
# 37101   489ae2aa008f021502940f251d4cce7f  e3b4998c7a498169dc7bce44e6bb6277
# 112569  69c590f7ffc7bf8db97190b6cb6ed62e  80ceebb4ee9b31afb6c6a916a574a1e2
# ...

# %%
Merge_itens_merge_products.query('product_category_name == "utilidades_domesticas"')['price'].quantile(.95)
# Out:
# 260.0

# %%
data_dos_pedidos = pd.read_csv('C://Users/ACER/Documents/CURSOS/Formação Cientista de Dados/dados_totais/olist_order_items_dataset.csv', 
                          index_col='order_id',
                          usecols=['order_id', 'shipping_limit_date'],
                          parse_dates=['shipping_limit_date'])\
    .query('shipping_limit_date >= "2018-01-01" and shipping_limit_date <= "2018-12-31"')
data_dos_pedidos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 62511 entries, 000229ec398224ef6ca0657da4fc703e to fffe41c64501cc87c801fd61db3f6244
# Data columns (total 1 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   shipping_limit_date  62511 non-null  datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 976.7+ KB

# %%
df_orders=pd.read_csv('C://Users/ACER/Documents/CURSOS/Formação Cientista de Dados/dados_totais/olist_orders_dataset.csv',usecols= ['order_id', 'order_status'])

# %%
df_payments=pd.read_csv('C://Users/ACER/Documents/CURSOS/Formação Cientista de Dados/dados_totais/olist_order_payments_dataset.csv',usecols= ['order_id', 'payment_type', 'payment_value'])

# %%
orders=df_orders.set_index('order_id').sort_index()

# %%
payments=df_payments.groupby('order_id')['payment_value'].sum()

# %%
vendas_produtos_filtra_data = data_dos_pedidos.merge(orders,on='order_id')

# %%
vendas_produtos_filtra_data
# Out:
#                                  shipping_limit_date order_status
# order_id
# 000229ec398224ef6ca0657da4fc703e 2018-01-18 14:48:30    delivered
# 00024acbcdf0a6daa1e931b038114c75 2018-08-15 10:10:18    delivered
# 000576fe39319847cbb9d288c5617fa6 2018-07-10 12:30:45    delivered
# 0005a1a1728c9d785b8e2b08b904576c 2018-03-26 18:31:29    delivered
# 0005f50442cb953dcd1d21e1fb923495 2018-07-06 14:10:56    delivered
# ...                                              ...          ...
# fffb2ef8874127f75b52b643880fd7e0 2018-04-09 05:08:33    delivered
# fffbee3b5462987e66fb49b1c5411df2 2018-06-28 09:58:03    delivered
# fffc94f6ce00a00581880bf54a75a037 2018-05-02 04:11:01    delivered
# fffcd46ef2263f404302a634eb57f7eb 2018-07-20 04:31:48    delivered
# fffe41c64501cc87c801fd61db3f6244 2018-06-12 17:10:13    delivered
#
# [62511 rows x 2 columns]

# %%
produto_datas_filtrado = vendas_produtos_filtra_data.query('order_status in ("delivered", "shipped", "invoiced")')
produto_datas_filtrado
# Out:
#                                  shipping_limit_date order_status
# order_id
# 000229ec398224ef6ca0657da4fc703e 2018-01-18 14:48:30    delivered
# 00024acbcdf0a6daa1e931b038114c75 2018-08-15 10:10:18    delivered
# 000576fe39319847cbb9d288c5617fa6 2018-07-10 12:30:45    delivered
# 0005a1a1728c9d785b8e2b08b904576c 2018-03-26 18:31:29    delivered
# 0005f50442cb953dcd1d21e1fb923495 2018-07-06 14:10:56    delivered
# ...                                              ...          ...
# fffb2ef8874127f75b52b643880fd7e0 2018-04-09 05:08:33    delivered
# fffbee3b5462987e66fb49b1c5411df2 2018-06-28 09:58:03    delivered
# fffc94f6ce00a00581880bf54a75a037 2018-05-02 04:11:01    delivered
# fffcd46ef2263f404302a634eb57f7eb 2018-07-20 04:31:48    delivered
# fffe41c64501cc87c801fd61db3f6244 2018-06-12 17:10:13    delivered
#
# [62141 rows x 2 columns]

# %%
type(produto_datas_filtrado.shipping_limit_date.iloc[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
df_orders
# Out:
#                                order_id order_status
# 0      e481f51cbdc54678b7cc49136f2d6af7    delivered
# 1      53cdb2fc8bc7dce0b6741e2150273451    delivered
# 2      47770eb9100c2d0c44946d9cf07ec65d    delivered
# 3      949d5b44dbf5de918fe9c16f97b45f8a    delivered
# 4      ad21c59c0840e6cb83a9ceb5573f8159    delivered
# ...                                 ...          ...
# 99436  9c5dedf39a927c1b2549525ed64a053c    delivered
# 99437  63943bddc261676b46f01ca7ac2f7bd8    delivered
# 99438  83c1379a015df1e13d02aae0204711ab    delivered
# 99439  11c177c8e97725db2631073c19f07b62    delivered
# 99440  66dea50a8b16d9b4dee7af250b4be1a5    delivered
#
# [99441 rows x 2 columns]

# %%
pd.to_datetime(produto_datas_filtrado.shipping_limit_date)
# Out:
# order_id
# 000229ec398224ef6ca0657da4fc703e   2018-01-18 14:48:30
# 00024acbcdf0a6daa1e931b038114c75   2018-08-15 10:10:18
# 000576fe39319847cbb9d288c5617fa6   2018-07-10 12:30:45
# 0005a1a1728c9d785b8e2b08b904576c   2018-03-26 18:31:29
# 0005f50442cb953dcd1d21e1fb923495   2018-07-06 14:10:56
#                                            ...
# fffb2ef8874127f75b52b643880fd7e0   2018-04-09 05:08:33
# fffbee3b5462987e66fb49b1c5411df2   2018-06-28 09:58:03
# fffc94f6ce00a00581880bf54a75a037   2018-05-02 04:11:01
# fffcd46ef2263f404302a634eb57f7eb   2018-07-20 04:31:48
# fffe41c64501cc87c801fd61db3f6244   2018-06-12 17:10:13
# Name: shipping_limit_date, Length: 62141, dtype: datetime64[ns]

# %%
def converte_str_para_data(x):
    x = x[:10]
    x = datetime.strptime(x, '%Y-%m-%d')
    return x

# %%
produto_datas_filtrado['data_dt'] = pd.to_datetime(produto_datas_filtrado.shipping_limit_date)
produto_datas_filtrado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 62141 entries, 000229ec398224ef6ca0657da4fc703e to fffe41c64501cc87c801fd61db3f6244
# Data columns (total 3 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   shipping_limit_date  62141 non-null  datetime64[ns]
#  1   order_status         62141 non-null  object
#  2   data_dt              62141 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), object(1)
# memory usage: 3.9+ MB
# C:\Users\ACER\AppData\Local\Temp/ipykernel_12176/3134069765.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   produto_datas_filtrado['data_dt'] = pd.to_datetime(produto_datas_filtrado.shipping_limit_date)

# %%
pd.merge(produto_datas_filtrado, Merge_itens_merge_products, 
         on='order_id', how='inner')\
    .groupby('product_category_name')\
    ['price']\
    .sum()\
    .sort_values(ascending=False)\
    .head(10)
# Out:
# product_category_name
# beleza_saude              905732.35
# relogios_presentes        788376.36
# cama_mesa_banho           761711.10
# informatica_acessorios    754571.58
# esporte_lazer             638131.40
# moveis_decoracao          594395.63
# utilidades_domesticas     561093.70
# automotivo                393559.38
# bebes                     289630.87
# ferramentas_jardim        289051.58
# Name: price, dtype: float64

# %%
df_review = pd.read_csv('C://Users/ACER/Documents/CURSOS/Formação Cientista de Dados/dados_totais/olist_order_reviews_dataset.csv')

# %%
df_review
# Out:
#                               review_id                          order_id  \
# 0      7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1      80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2      228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3      e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4      f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
# ...                                 ...                               ...
# 99219  574ed12dd733e5fa530cfd4bbf39d7c9  2a8c23fee101d4d5662fa670396eb8da
# 99220  f3897127253a9592a73be9bdfdf4ed7a  22ec9f0669f784db00fa86d035cf8602
# 99221  b3de70c89b1510c4cd3d0649fd302472  55d4004744368f5571d1f590031933e4
# 99222  1adeb9d84d72fe4e337617733eb85149  7725825d039fc1f0ceb7635e3f7d9206
# 99223  efe49f1d6f951dd88b51e6ccd4cc548f  90531360ecb1eec2a1fbb265a0db0508
#
#        review_score review_comment_title  \
# ...

# %%
Merge_reviews = Merge_itens_merge_products.merge(df_review,on='order_id')

# %%
Merge_reviews
# Out:
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       130898c0987d1801452a8ed92a670612              1
# 2       532ed5e14e24ae1f0d735b91524b98b9              1
# 3       6f8c31653edb8c83e1a739408b5ff750              1
# 4       7d19f4ef4d04461989632411b7e588b9              1
# ...                                  ...            ...
# 112367  ffebd80e3291e811c308365936897efd              1
# 112368  ffee31fb4b5e35c9123608015637c495              1
# 112369  fff7c4452f050315db1b3f24d9df5fcd              1
# 112370  fffa82886406ccf10c7b4e35c4ff2788              1
# 112371  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# ...

# %%
Merge_reviews.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  130898c0987d1801452a8ed92a670612              1
# 2  532ed5e14e24ae1f0d735b91524b98b9              1
# 3  6f8c31653edb8c83e1a739408b5ff750              1
# 4  7d19f4ef4d04461989632411b7e588b9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 2  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 3  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 4  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
#
#    shipping_limit_date  price  freight_value product_category_name  \
# 0  2017-09-19 09:45:35   58.9          13.29            cool_stuff
# 1  2017-07-05 02:44:11   55.9          17.96            cool_stuff
# ...

# %%
Merge_reviews.order_item_id.value_counts()
# Out:
# 1     98465
# 2      9766
# 3      2270
# 4       959
# 5       456
# 6       252
# 7        58
# 8        36
# 9        28
# 10       25
# 11       17
# 12       12
# 13        7
# 14        6
# 15        4
# 16        2
# 17        2
# 18        2
# 19        2
# 20        2
# 21        1
# Name: order_item_id, dtype: int64

# %%
filtro_mais_que_um_produto = Merge_reviews.order_item_id > 1

# %%
id_dos_pedidos_com_mais_de_um_produto = Merge_reviews[filtro_mais_que_um_produto].order_id.unique()

# %%
id_dos_pedidos_com_mais_de_um_produto
# Out:
# array(['c9ef97d2854afe64a3b4488bc2836af6',
#        '45211f00dfa76aed1c20d6910d973222',
#        '09268d8b25dd31ae78b464efd453d069', ...,
#        'ffb18bf111fa70edf316eb0390427986',
#        'ffd6f465cab015b452d398ac1f5d978a',
#        'ffe4b41e99d39f0b837a239110260530'], dtype=object)

# %%
pedidos_com_apenas_um_produto = Merge_reviews[~ Merge_reviews.order_id.isin(id_dos_pedidos_com_mais_de_um_produto)]
pedidos_com_apenas_um_produto
# Out:
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       130898c0987d1801452a8ed92a670612              1
# 2       532ed5e14e24ae1f0d735b91524b98b9              1
# 3       6f8c31653edb8c83e1a739408b5ff750              1
# 4       7d19f4ef4d04461989632411b7e588b9              1
# ...                                  ...            ...
# 112367  ffebd80e3291e811c308365936897efd              1
# 112368  ffee31fb4b5e35c9123608015637c495              1
# 112369  fff7c4452f050315db1b3f24d9df5fcd              1
# 112370  fffa82886406ccf10c7b4e35c4ff2788              1
# 112371  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# ...

# %%
pedidos_com_apenas_um_produto.order_item_id.value_counts()
# Out:
# 1    88699
# Name: order_item_id, dtype: int64

# %%
avaliacoes_pedidos_um_produto = pd.merge(pedidos_com_apenas_um_produto, Merge_reviews, 
         on='order_id', how='inner')

# %%
avaliacoes_pedidos_um_produto.head()
# Out:
#                            order_id  order_item_id_x  \
# 0  00010242fe8c5a6d1ba2dd792cb16214                1
# 1  130898c0987d1801452a8ed92a670612                1
# 2  532ed5e14e24ae1f0d735b91524b98b9                1
# 3  6f8c31653edb8c83e1a739408b5ff750                1
# 4  7d19f4ef4d04461989632411b7e588b9                1
#
#                        product_id_x                       seller_id_x  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 2  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 3  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 4  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
#
#   shipping_limit_date_x  price_x  freight_value_x product_category_name_x  \
# 0   2017-09-19 09:45:35     58.9            13.29              cool_stuff
# ...

# %%
avaliacoes_pedidos_um_produto['product_id_x'].mode()
# Out:
# 0    99a4788cb24856965c36a24e339b6058
# dtype: object

# %%
avaliacoes_pedidos_um_produto.set_index('product_id_x').loc['99a4788cb24856965c36a24e339b6058']
# Out:
#                                                           order_id  \
# product_id_x
# 99a4788cb24856965c36a24e339b6058  0006ec9db01a64e59a68b2c340bf65a7
# 99a4788cb24856965c36a24e339b6058  00c763284c0056eed753352f5559ff0a
# 99a4788cb24856965c36a24e339b6058  0368f4fdb586fe3cde123934d4ab5b5e
# 99a4788cb24856965c36a24e339b6058  03b5a8a7f871d2a792f7af458fe13b4a
# 99a4788cb24856965c36a24e339b6058  0403bed7b44fb735b6af72505c57fdd3
# ...                                                            ...
# 99a4788cb24856965c36a24e339b6058  fd188acaf0be6dba0ce1ec1ca5005ceb
# 99a4788cb24856965c36a24e339b6058  fd52368d8373ad4158396078bf5ad004
# 99a4788cb24856965c36a24e339b6058  fe4e63c3ce772bf558a089b256e4e8d7
# 99a4788cb24856965c36a24e339b6058  fe575916daa713f9830a8b7362121621
# 99a4788cb24856965c36a24e339b6058  ff79282c8f4c58df02fde009ad02d009
#
#                                   order_item_id_x  \
# product_id_x
# 99a4788cb24856965c36a24e339b6058                1
# ...

# %%
review_score_produtos_agg = Merge_reviews.agg

# %%
review_score_produtos_agg
# Out:
# <bound method DataFrame.aggregate of                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       130898c0987d1801452a8ed92a670612              1
# 2       532ed5e14e24ae1f0d735b91524b98b9              1
# 3       6f8c31653edb8c83e1a739408b5ff750              1
# 4       7d19f4ef4d04461989632411b7e588b9              1
# ...                                  ...            ...
# 112367  ffebd80e3291e811c308365936897efd              1
# 112368  ffee31fb4b5e35c9123608015637c495              1
# 112369  fff7c4452f050315db1b3f24d9df5fcd              1
# 112370  fffa82886406ccf10c7b4e35c4ff2788              1
# 112371  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# ...

# %%
review_score_produtos_atualizacao = avaliacoes_pedidos_um_produto.groupby('product_id_x')['review_score_y'].agg(['mean', 'count'])

# %%
review_score_produtos_atualizacao
# Out:
#                                   mean  count
# product_id_x
# 00066f42aeeb9f3007548bb9d3f33c38   5.0      1
# 00088930e925c41fd95ebfe695fd2655   4.0      1
# 0009406fd7479715e4bef61dd91f2462   1.0      1
# 000b8f95fcb9e0096488278317764d19   5.0      2
# 000d9be29b5207b54e86aa1b1ac54872   5.0      1
# ...                                ...    ...
# fff6177642830a9a94a0f2cba5e476d1   4.5      2
# fff81cc3158d2725c0655ab9ba0f712c   4.0      1
# fff9553ac224cec9d15d49f5a263411f   5.0      1
# fffdb2d0ec8d6a61f0a0a0db3f25b441   5.0      5
# fffe9eeff12fcbd74a2f2b007dde0c58   4.0      1
#
# [29323 rows x 2 columns]

# %%
media_dos_scores = review_score_produtos_atualizacao.sort_values(by=['mean', 'count'], ascending=[False, False])

# %%
media_dos_scores['count_neg'] = media_dos_scores['count'] * -1

# %%
media_dos_scores
# Out:
#                                   mean  count  count_neg
# product_id_x
# 2722b7e5f68e776d18fe901638034e54   5.0     13        -13
# 4c8b28305f570899b6ded964ddd234a9   5.0     11        -11
# 59c1840441f4df065f52760bf51a8442   5.0     11        -11
# 83aae8023b8feda53259f63e0ec06390   5.0     10        -10
# a7d756e8f7c4b7e5b679e248a57d91ec   5.0     10        -10
# ...                                ...    ...        ...
# ff5ecb2f7628793844e861076ab8e467   1.0      1         -1
# ff6154cee42bf2718cca4865f0620e04   1.0      1         -1
# ff9dfd2acec3dff6be51b4d28bed8768   1.0      1         -1
# ffa1ce7f2a287ca5e369673bd77d43de   1.0      1         -1
# ffbfa9e143fda4420454d0f4e88a3cd5   1.0      1         -1
#
# [29323 rows x 3 columns]

# %%
media_dos_scores.groupby('mean')['count'].max().loc[[5, 1]]
# Out:
# mean
# 5    13
# 1     5
# Name: count, dtype: int64

# %%
rank_count = media_dos_scores.reset_index().drop(columns=['product_id_x', 'count']).groupby(['mean']).rank(method='dense')

# %%
media_dos_scores['rank_count'] = rank_count.values

# %%
rank_tipo_ascending_false = media_dos_scores.reset_index().groupby(['mean'])['count'].rank(method='dense', 
                                                                                           ascending=False)
